# %% [markdown]
# <a href="https://colab.research.google.com/github/Alex-Mendoza/Data-Science/blob/main/PreEntrega_AlexMendoza.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Enfermedades cardiovasculares **

# %% [markdown]
# # **Objetivo**

# %% [markdown]
# *El objetivo de este análisis es investigar una variedad de factores relacionados con la salud y sus interconexiones para clasificar la diabetes con precisión. Estos factores incluyen aspectos como la edad, el sexo, el índice de masa corporal (IMC), la hipertensión, las enfermedades cardíacas, los antecedentes de tabaquismo, el nivel de HbA1c y el nivel de glucosa en sangre. Este examen exhaustivo no sólo proporcionará información sobre los patrones y tendencias del riesgo de diabetes, sino que también creará una base sólida para futuras investigaciones. Específicamente, se pueden desarrollar investigaciones sobre cómo estas variables interactúan e influyen en la aparición y progresión de la diabetes, conocimiento crucial para mejorar la atención al paciente y los resultados en esta área cada vez más crítica de la atención médica.*

# %% [markdown]
# # **Conocimiento del dominio**

# %% [markdown]
# **Age/Edad:** La edad es un factor importante para predecir el riesgo de diabetes. A medida que las personas envejecen, aumenta su riesgo de desarrollar diabetes. Esto se debe en parte a factores como la reducción de la actividad física, los cambios en los niveles hormonales y una mayor probabilidad de desarrollar otras afecciones de salud que pueden contribuir a la diabetes.
#
# **Gender/Género:** El género puede desempeñar un papel en el riesgo de diabetes, aunque el efecto puede variar. Por ejemplo, las mujeres con antecedentes de diabetes gestacional (diabetes durante el embarazo) tienen un mayor riesgo de desarrollar diabetes tipo 2 en el futuro. Además, algunos estudios han sugerido que los hombres pueden tener un riesgo ligeramente mayor de diabetes en comparación con las mujeres.
#
# **Body Mass Index/Índice de masa corporal (IMC):** El IMC es una medida de grasa corporal basada en la altura y el peso de una persona. Se utiliza comúnmente como indicador del estado de peso general y puede ser útil para predecir el riesgo de diabetes. Un IMC más alto se asocia con una mayor probabilidad de desarrollar diabetes tipo 2. El exceso de grasa corporal, especialmente alrededor de la cintura, puede provocar resistencia a la insulina y afectar la capacidad del cuerpo para regular los niveles de azúcar en sangre.
#
# **Hypertension/Hipertensión:** La hipertensión, o presión arterial alta, es una afección que a menudo coexiste con la diabetes. Las dos condiciones comparten factores de riesgo comunes y pueden contribuir al desarrollo de cada una. Tener hipertensión aumenta el riesgo de desarrollar diabetes tipo 2 y viceversa. Ambas condiciones pueden tener efectos perjudiciales sobre la salud cardiovascular.
#
# **Heart Disease/Enfermedad cardíaca:** Las enfermedades cardíacas, incluidas afecciones como la enfermedad de las arterias coronarias y la insuficiencia cardíaca, se asocian con un mayor riesgo de diabetes. La relación entre las enfermedades cardíacas y la diabetes es bidireccional, lo que significa que tener una condición aumenta el riesgo de desarrollar la otra. Esto se debe a que comparten muchos factores de riesgo comunes, como la obesidad, la presión arterial alta y el colesterol alto.
#
# **Smoking History/Historial de tabaquismo:** El tabaquismo es un factor de riesgo modificable para la diabetes. Se ha descubierto que fumar cigarrillos aumenta el riesgo de desarrollar diabetes tipo 2. Fumar puede contribuir a la resistencia a la insulina y alterar el metabolismo de la glucosa. Dejar de fumar puede reducir significativamente el riesgo de desarrollar diabetes y sus complicaciones.
#
# **HbA1c Level/Nivel de HbA1c:** HbA1c (hemoglobina glucosilada) es una medida del nivel promedio de glucosa en sangre durante los últimos 2 a 3 meses. Proporciona información sobre el control del azúcar en sangre a largo plazo. Los niveles más altos de HbA1c indican un peor control glucémico y se asocian con un mayor riesgo de desarrollar diabetes y sus complicaciones.
#
# **Blood Glucose Level/Nivel de glucosa en sangre:** El nivel de glucosa en sangre se refiere a la cantidad de glucosa (azúcar) presente en la sangre en un momento dado. Los niveles elevados de glucosa en sangre, especialmente en ayunas o después de consumir carbohidratos, pueden indicar una regulación alterada de la glucosa y aumentar el riesgo de desarrollar diabetes. El control regular de los niveles de glucosa en sangre es importante en el diagnóstico y tratamiento de la diabetes.
#
# ✔️ Estas características, cuando se combinan y analizan con técnicas estadísticas y de aprendizaje automático adecuadas, pueden ayudar a predecir el riesgo de un individuo de desarrollar diabetes.

# %% [markdown]
# # **Librerías importadas**

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn.metrics
from sklearn.svm import SVC
from sklearn import preprocessing
import sklearn.metrics
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
from tensorflow import keras

df = pd.read_csv ('https://docs.google.com/spreadsheets/d/e/2PACX-1vRDE-AC2Zs1o7sWyQ-DtS0p8xfui9qLDSwjyAlT4MAjcZwixRIfLbgHmmmH_091rSnczMhErtJlGbNx/pub?gid=517522836&single=true&output=csv')

# %%
from google.colab import drive
import os

# Ruta al archivo CSV
file_path = 'https://docs.google.com/spreadsheets/d/e/2PACX-1vRDE-AC2Zs1o7sWyQ-DtS0p8xfui9qLDSwjyAlT4MAjcZwixRIfLbgHmmmH_091rSnczMhErtJlGbNx/pub?gid=517522836&single=true&output=csv'

# Leer el archivo CSV en un DataFrame de pandas
df = pd.read_csv ('https://docs.google.com/spreadsheets/d/e/2PACX-1vRDE-AC2Zs1o7sWyQ-DtS0p8xfui9qLDSwjyAlT4MAjcZwixRIfLbgHmmmH_091rSnczMhErtJlGbNx/pub?gid=517522836&single=true&output=csv')

# Mostrar las primeras filas del DataFrame
df = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vRDE-AC2Zs1o7sWyQ-DtS0p8xfui9qLDSwjyAlT4MAjcZwixRIfLbgHmmmH_091rSnczMhErtJlGbNx/pub?gid=517522836&single=true&output=csv')
df_copy = df
df.head()
# Out:
#   General_Health                  Checkup Exercise Heart_Disease Skin_Cancer  \
# 0           Poor  Within the past 2 years       No            No          No
# 1      Very Good     Within the past year       No           Yes          No
# 2      Very Good     Within the past year      Yes            No          No
# 3           Poor     Within the past year      Yes           Yes          No
# 4           Good     Within the past year       No            No          No
#
#   Other_Cancer Depression Diabetes Arthritis     Sex Age_Category  \
# 0           No         No       No       Yes  Female        70-74
# 1           No         No      Yes        No  Female        70-74
# 2           No         No      Yes        No  Female        60-64
# 3           No         No      Yes        No    Male        75-79
# 4           No         No       No        No    Male          80+
#
#    Height_(cm)  Weight_(kg)   BMI Smoking_History  Alcohol_Consumption  \
# ...

# %%
df.columns
# Out:
# Index(['General_Health', 'Checkup', 'Exercise', 'Heart_Disease', 'Skin_Cancer',
#        'Other_Cancer', 'Depression', 'Diabetes', 'Arthritis', 'Sex',
#        'Age_Category', 'Height_(cm)', 'Weight_(kg)', 'BMI', 'Smoking_History',
#        'Alcohol_Consumption', 'Fruit_Consumption',
#        'Green_Vegetables_Consumption', 'FriedPotato_Consumption'],
#       dtype='object')

# %%
df.shape
# Out:
# (308854, 19)

# %%
##Impresión de valores únicos para columnas seleccionadas que pueden no contener valores binarios ("sí o no")
print(df['Checkup'].unique())
print('')
print(df['General_Health'].unique())
print('')
print(df['Diabetes'].unique())
print('')
print(df['Age_Category'].unique())
# Out:
# ['Within the past 2 years' 'Within the past year' '5 or more years ago'
#  'Within the past 5 years' 'Never']
#
# ['Poor' 'Very Good' 'Good' 'Fair' 'Excellent']
#
# ['No' 'Yes' 'No, pre-diabetes or borderline diabetes'
#  'Yes, but female told only during pregnancy']
#
# ['70-74' '60-64' '75-79' '80+' '65-69' '50-54' '45-49' '18-24' '30-34'
#  '55-59' '35-39' '40-44' '25-29']

# %%
df.describe()
# Out:
#        Height_(cm)  Weight_(kg)       BMI  Alcohol_Consumption  \
# count    308854.00    308854.00 308854.00            308854.00
# mean        170.62        83.59     28.63                 5.10
# std          10.66        21.34      6.52                 8.20
# min          91.00        24.95     12.02                 0.00
# 25%         163.00        68.04     24.21                 0.00
# 50%         170.00        81.65     27.44                 1.00
# 75%         178.00        95.25     31.85                 6.00
# max         241.00       293.02     99.33                30.00
#
#        Fruit_Consumption  Green_Vegetables_Consumption  \
# count          308854.00                     308854.00
# mean               29.84                         15.11
# std                24.88                         14.93
# min                 0.00                          0.00
# 25%                12.00                          4.00
# 50%                30.00                         12.00
# ...

# %%
a = len(df['Heart_Disease'][df['Heart_Disease']=='Yes'])
b = len(df['Heart_Disease'][df['Heart_Disease']=='No'])
print('Number of people with heart disease:',a)
print('Number of people without heart disease:',b)

print('Ratio of Heart_Disease + / Heart_Disease -:',a/b)
# Out:
# Number of people with heart disease: 24971
# Number of people without heart disease: 283883
# Ratio of Heart_Disease + / Heart_Disease -: 0.08796229432547915

# %% [markdown]
# # **EDA**

# %%
#Impresión de valores únicos para columnas seleccionadas que pueden no contener valores binarios ("sí o no")
data = df.replace({'No':0,'Yes':1})

data = df.replace({'Within the past 2 years':2, 'Within the past year':1,
       '5 or more years ago':4, 'Within the past 5 years':3, 'Never':0})

data = df.replace({'Poor':0, 'Very Good':3, 'Good':2, 'Fair':1, 'Excellent':4})

data = df.replace({'Male':1,'Female':2})

data = df.replace({'70-74':10, '60-64':8, '75-79':11, '80+':12, '65-69':9, '50-54':6, '45-49':5, '18-24':0, '30-34':2,
 '55-59':7, '35-39':3, '40-44':4, '25-29':1,})

data = df.replace({'No':0, 'Yes':3, 'No, pre-diabetes or borderline diabetes':1,
 'Yes, but female told only during pregnancy':2})

# %%
data.corr().Heart_Disease
# Out:
# Exercise                       -0.10
# Heart_Disease                   1.00
# Skin_Cancer                     0.09
# Other_Cancer                    0.09
# Depression                      0.03
# Diabetes                        0.18
# Arthritis                       0.15
# Height_(cm)                     0.02
# Weight_(kg)                     0.05
# BMI                             0.04
# Smoking_History                 0.11
# Alcohol_Consumption            -0.04
# Fruit_Consumption              -0.02
# Green_Vegetables_Consumption   -0.02
# FriedPotato_Consumption        -0.01
# Name: Heart_Disease, dtype: float64

# %%
#Weight vs. BMI
plt.scatter(data['Weight_(kg)'],data['BMI'])
plt.title('Weight vs. BMI')
plt.xlabel('Weight')
plt.ylabel('BMI')
# Out:
# Text(0, 0.5, 'BMI')

# %%
plt.hist(data['BMI'])
plt.hist(data['Green_Vegetables_Consumption'])
plt.title('BMI vs. Green_Vegetables_Consumption')
# Out:
# Text(0.5, 1.0, 'BMI vs. Green_Vegetables_Consumption')

# %%
plt.violinplot(data['Weight_(kg)'])
plt.title('Weight Distribution')
plt.xlabel('Median')
plt.ylabel('Weight(kg)')
plt.axhline(np.mean(data['Weight_(kg)']))

# %% [markdown]
# # **Creando un modelo de regresión logística**

# %%
list(df.columns)
# Out:
# ['General_Health',
#  'Checkup',
#  'Exercise',
#  'Heart_Disease',
#  'Skin_Cancer',
#  'Other_Cancer',
#  'Depression',
#  'Diabetes',
#  'Arthritis',
#  'Sex',
#  'Age_Category',
#  'Height_(cm)',
#  'Weight_(kg)',
#  'BMI',
#  'Smoking_History',
#  'Alcohol_Consumption',
#  'Fruit_Consumption',
#  'Green_Vegetables_Consumption',
#  'FriedPotato_Consumption']

# %%
#Encontrar lista de variables categóricas
s = (df.dtypes == "object")
cat_cols = list(s[s].index)
print(cat_cols)
# Out:
# ['General_Health', 'Checkup', 'Exercise', 'Heart_Disease', 'Skin_Cancer', 'Other_Cancer', 'Depression', 'Diabetes', 'Arthritis', 'Sex', 'Age_Category', 'Smoking_History']

# %%
#Observando el número de valores únicos en cada característica categórica
df['General_Health'].unique()
# Out:
# array(['Poor', 'Very Good', 'Good', 'Fair', 'Excellent'], dtype=object)

# %%
df["General_Health"].replace(" ", "_", regex = True, inplace = True)
df["Checkup"].replace(" ", "_", regex = True, inplace = True)
df["Diabetes"].replace(" ", "_", regex = True, inplace = True)
df.head()
# Out:
#   General_Health                  Checkup Exercise Heart_Disease Skin_Cancer  \
# 0           Poor  Within_the_past_2_years       No            No          No
# 1      Very_Good     Within_the_past_year       No           Yes          No
# 2      Very_Good     Within_the_past_year      Yes            No          No
# 3           Poor     Within_the_past_year      Yes           Yes          No
# 4           Good     Within_the_past_year       No            No          No
#
#   Other_Cancer Depression Diabetes Arthritis     Sex Age_Category  \
# 0           No         No       No       Yes  Female        70-74
# 1           No         No      Yes        No  Female        70-74
# 2           No         No      Yes        No  Female        60-64
# 3           No         No      Yes        No    Male        75-79
# 4           No         No       No        No    Male          80+
#
#    Height_(cm)  Weight_(kg)   BMI Smoking_History  Alcohol_Consumption  \
# ...

# %%
#observamos la cantidad de datos  por cada columna
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 308854 entries, 0 to 308853
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   General_Health                308854 non-null  object
#  1   Checkup                       308854 non-null  object
#  2   Exercise                      308854 non-null  object
#  3   Heart_Disease                 308854 non-null  object
#  4   Skin_Cancer                   308854 non-null  object
#  5   Other_Cancer                  308854 non-null  object
#  6   Depression                    308854 non-null  object
#  7   Diabetes                      308854 non-null  object
#  8   Arthritis                     308854 non-null  object
#  9   Sex                           308854 non-null  object
#  10  Age_Category                  308854 non-null  object
#  11  Height_(cm)                   308854 non-null  float64
# ...

# %%
## Creación de columnas numéricas y categóricas
V_numerica = df.select_dtypes(include=['float64']).columns.sort_values()
V_categorica = df.select_dtypes(include=['object']).columns.sort_values()

# %%
print(f'Hay {len(V_numerica)} Variables númericas')
print(f'Hay {len(V_categorica)} Variables categóricas')
# Out:
# Hay 7 Variables númericas
# Hay 12 Variables categóricas

# %%
V_numerica
# Out:
# Index(['Alcohol_Consumption', 'BMI', 'FriedPotato_Consumption',
#        'Fruit_Consumption', 'Green_Vegetables_Consumption', 'Height_(cm)',
#        'Weight_(kg)'],
#       dtype='object')

# %%
V_categorica
# Out:
# Index(['Age_Category', 'Arthritis', 'Checkup', 'Depression', 'Diabetes',
#        'Exercise', 'General_Health', 'Heart_Disease', 'Other_Cancer', 'Sex',
#        'Skin_Cancer', 'Smoking_History'],
#       dtype='object')

# %%
label_encoder = preprocessing.LabelEncoder()

for i in (df[V_categorica]):
  df[i] = label_encoder.fit_transform(df[i])

df.head()
# Out:
#    General_Health  Checkup  Exercise  Heart_Disease  Skin_Cancer  \
# 0               3        2         0              0            0
# 1               4        4         0              1            0
# 2               4        4         1              0            0
# 3               3        4         1              1            0
# 4               2        4         0              0            0
#
#    Other_Cancer  Depression  Diabetes  Arthritis  Sex  Age_Category  \
# 0             0           0         0          1    0            10
# 1             0           0         2          0    0            10
# 2             0           0         2          0    0             8
# 3             0           0         2          0    1            11
# 4             0           0         0          0    1            12
#
#    Height_(cm)  Weight_(kg)   BMI  Smoking_History  Alcohol_Consumption  \
# 0       150.00        32.66 14.54                1                 0.00
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn.metrics
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
from tensorflow.python.ops.gen_nn_ops import data_format_dim_map
#Caracteríticas
X = df.drop(['Heart_Disease'],axis=1)

#Etiquetas
y = df['Heart_Disease']

#Dividir los datos en entrenamiento y prueba; 70% formación, 30% pruebas
#La división #80-20 produce peores resultados
x_train, x_test, y_train, y_test = train_test_split(X,y,test_size=.3,train_size=.7,random_state=12)

#Creación de un objeto de regresión logística; Configurar max_iter=20000 para permitir que el algoritmo converja
log_model = LogisticRegression(max_iter=20000)

#Ajustar los datos de entrenamiento a un modelo logístico
log_model.fit(x_train,y_train)

#Entrenando el modelo de registro en los datos x_test
y_pred = log_model.predict(x_test)

#Imprimir la puntuación del log_model ajustado en los datos de prueba
print("Logistic Model Score on Testing Data:",log_model.score(x_test,y_test))

#Imprimir la puntuación del log_model ajustado en los datos de prueba
print("Logistic Model Score on Testing Data:",log_model.score(x_test,y_test))

#Devolver la precisión del modelo en los datos de entrenamiento y prueba.
lmstr = log_model.score(x_train,y_train)
lmste = log_model.score(x_test,y_test)
# Out:
# Logistic Model Score on Testing Data: 0.9181497350443032
# Logistic Model Score on Testing Data: 0.9181497350443032

# %% [markdown]
# # **Matriz de confusión**

# %%
#Creating a confusion matrix;
#True Neg == Top left, True Pos == Abajo a la derecha
#False Neg == Bottom Left, False Pos == Arriba a la derecha
confusion_matrix = sklearn.metrics.confusion_matrix(y_test,y_pred)
sklearn.metrics.ConfusionMatrixDisplay(confusion_matrix).plot()

# %%
lm_coefs = pd.DataFrame({"Coefs":log_model.coef_[:][0],"Column Names":x_train.columns})
print('Intercept:',log_model.intercept_)
lm_coefs
# Out:
# Intercept: [-0.03986651]
#     Coefs                  Column Names
# 0   -0.07                General_Health
# 1    0.15                       Checkup
# 2   -0.29                      Exercise
# 3    0.11                   Skin_Cancer
# 4    0.22                  Other_Cancer
# 5    0.45                    Depression
# 6    0.35                      Diabetes
# 7    0.43                     Arthritis
# 8    0.96                           Sex
# 9    0.28                  Age_Category
# 10  -0.04                   Height_(cm)
# 11   0.03                   Weight_(kg)
# 12  -0.06                           BMI
# 13   0.50               Smoking_History
# 14  -0.02           Alcohol_Consumption
# 15  -0.00             Fruit_Consumption
# 16  -0.00  Green_Vegetables_Consumption
# 17   0.00       FriedPotato_Consumption

# %% [markdown]
# # **Coeficientes**

# %% [markdown]
# Los coeficientes de estos datos nos dicen lo siguiente:
#
# (1) Skin_Cancer/El cáncer de piel, Other_Cancer/otro cáncer, Arthritis/Artritis, Height/la altura, Weight/el peso y el smoking/tabaquismo tienen una correlación positiva con las Heart Disease/enfermedades cardíacas.
#
# (2) General_health/La salud general, el número de controles, el ejercicio/exercise, la depresión/deprression, el IMC/BMI, el consumo de alcohol/Alcohol_Consumption, el consumo de frutas/ Fruit Consumption, el consumo de vegetales verdes/ Green Vegetable Consumption/ y el consumo de papas fritas/Fried Potato Consumption se correlacionan negativamente con el riesgo de enfermedad cardíaca.
#
# A medida que aumentan las enfermedades cardíacas, todas las categorías en (1) tienden a aumentar con el tiempo, mientras que (2) disminuyen con el tiempo.
#
# La mayor correlación entre tener enfermedades del corazón parece ser tener diabetes.

# %% [markdown]
# # **Optimización del modelo utilizando los coeficientes más correlacionados**

# %% [markdown]
# *En mi modelo, todos los coeficientes son relativamente pequeños. A pesar de esto, con la esperanza de hacer que mi modelo sea más preciso y eficiente, hice un segundo modelo a continuación para ver si hay alguna mejora en mi nuevo modelo usando alguna característica del primer modelo que tenía un valor de coeficiente de .2 o superior.*

# %%
#Features
X = df[['Arthritis','Smoking_History','Age_Category','Diabetes','Depression']]

#Labels
y = df['Heart_Disease']

#Splitting the data into training and testing; 70% Training, 30% Testing
#80-20 yielded worse results
x_train, x_test, y_train, y_test = train_test_split(X,y,test_size=.3,train_size=.7,random_state=12)

#Creating a Logistic Regression Object
log_model_2 = LogisticRegression(max_iter=20000)

#Fitting the training data to a logistic model
log_model_2.fit(x_train,y_train)

#Training the log model on the x_test data
y_pred_2 = log_model_2.predict(x_test)

#printing the score(error) of the fitted log_model
print("Logistic Model Score on Training Data:",log_model_2.score(x_train,y_train))

#Printing the score of the fitted log_model on testing data
print("Logistic Model Score on Testing Data:",log_model_2.score(x_test,y_test))

lmstr_2 = log_model_2.score(x_train,y_train)
lmste_2 = log_model_2.score(x_test,y_test)
# Out:
# Logistic Model Score on Training Data: 0.9193235798831622
# Logistic Model Score on Testing Data: 0.9184195473628544

# %%
lm_coefs_2 = pd.DataFrame({"Coefs":log_model_2.coef_[:][0],"Column Names":x_train.columns})
print('Intercept:',log_model.intercept_)
lm_coefs_2
# Out:
# Intercept: [-0.03986651]
#    Coefs     Column Names
# 0   0.42        Arthritis
# 1   0.58  Smoking_History
# 2   0.29     Age_Category
# 3   0.44         Diabetes
# 4   0.38       Depression

# %%
#El modelo 2 funciona ligeramente peor que nuestro modelo original.
print(lmstr_2 - lmstr)
print(lmste_2 - lmste)

#Restar los puntajes de entrenamiento y pruebas del modelo 2 por el modelo 1 da como resultado un número negativo.
#Esto denota que el modelo 1 tenía mayores precisiones tanto para los datos de entrenamiento como para los de prueba.
# Out:
# 0.0003746582977562918
# 0.00026981231855116583

# %% [markdown]
# *Eliminar las columnas adicionales fuera de los valores de coeficiente inferiores a 0,2 cambió la puntuación del modelo en una cantidad muy pequeña para los datos de entrenamiento y los datos de prueba. Esto me dice que las columnas eliminadas, si bien siguen afectando ligeramente al modelo, no tienen un impacto notable en la puntuación general del modelo.
#
# Sin embargo, las puntuaciones por sí solas no dicen toda la verdad.*

# %%
confusion_matrix = sklearn.metrics.confusion_matrix(y_test,y_pred_2)
sklearn.metrics.ConfusionMatrixDisplay(confusion_matrix).plot()

# %% [markdown]
# *Ver la matriz de confusión del segundo modelo revela el hecho de que el segundo modelo no solo es ligeramente peor en cuanto a puntuación, sino que el segundo modelo también tiene un mayor número de falsos negativos que el primero. Además de eso, el segundo modelo clasifica erróneamente a casi todos los pacientes afectados como si no tuvieran una enfermedad cardíaca cuando en realidad la tienen (lo cual es incorrecto y peligroso).
#
# Entonces, si bien las otras columnas no tienen un gran impacto en lo que respecta a la puntuación, las columnas adicionales sí permiten que el modelo tenga predicciones más precisas.*

# %% [markdown]
# # **Calculando RMSE de ambos modelos.**

# %% [markdown]
# *RMSE es una métrica que se utiliza para calcular qué tan cerca están las estimaciones de sus valores reales. Cuanto menor sea nuestro valor RMSE, más preciso será nuestro modelo. Si bien utilicé la función de puntuación incorporada anteriormente, para validar aún más mi modelo, aún me gustaría usar RMSE como métrica de prueba adicional.*

# %%
mse_1 = sklearn.metrics.mean_squared_error(y_test,y_pred)
mse_2 = sklearn.metrics.mean_squared_error(y_test,y_pred_2)
print("Model 1 RMSE:",np.sqrt(mse_1),"Model 2 RMSE:",np.sqrt(mse_2))
print("Model with the lowest RMSE:", min(np.sqrt(mse_1),np.sqrt(mse_2)))
# Out:
# Model 1 RMSE: 0.2860948530744599 Model 2 RMSE: 0.28562292036379994
# Model with the lowest RMSE: 0.28562292036379994

# %% [markdown]
# *Como era de esperar, el modelo 1 tiene un RMSE más bajo que el segundo modelo.*

# %%
func = np.arange(-7,7,1)
equ = (np.exp(func))/(1 + np.exp(func))

for i in range(len(lm_coefs)-1):
    coef = lm_coefs.iloc[i][0]
    rate = coef * equ
    plt.plot(func,rate,label=(lm_coefs.iloc[i][1],lm_coefs.iloc[i][0]))

#source = https://www.freecodecamp.org/news/matplotlib-figure-size-change-plot-size-in-python/
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.title('Coefficients vs. Heart Disease')
plt.xlabel('Increase in Heart Disease')
plt.ylabel('Coefficient Rates')
# Out:
# Text(0, 0.5, 'Coefficient Rates')

# %% [markdown]
# # **Conclusiones**

# %% [markdown]
# *1) Los principales factores que contribuyen a las enfermedades cardíacas son el tabaquismo, junto con la diabetes.
#
# 2) Ambos modelos creados tuvieron una precisión de alrededor del 91 por ciento, sin embargo, el modelo uno funcionó ligeramente mejor en pequeñas cantidades decimales.
#
# 3) El modelo 1 fue capaz de predecir correctamente casi 400 pacientes más que tenían enfermedades cardíacas que el modelo 2, a pesar de que el modelo 2 utilizó solo los coeficientes más relevantes.
#
# 4) El modelo 2 tenía una tasa de falsos negativos más alta pero una tasa de falsos positivos más baja, mientras que el modelo 1 tenía una tasa de falsos negativos más baja pero una tasa de falsos positivos más alta.*
